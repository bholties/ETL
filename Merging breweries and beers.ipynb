# %%
import pandas as pd
import numpy as np

# %%
#file to connect to
beers_file = "beers.csv"

brewery_file = "breweries.csv"

# %%
#creating a pandas data frame with the craft beers csv file

craft_beers_df = pd.read_csv(beers_file, skiprows=[0])
craft_beers_df.head(100)
# Out:
#     Unnamed: 0    abv   ibu    id                 name  \
# 0            0  0.050   NaN  1436             Pub Beer
# 1            1  0.066   NaN  2265          Devil's Cup
# 2            2  0.071   NaN  2264  Rise of the Phoenix
# 3            3  0.090   NaN  2263             Sinister
# 4            4  0.075   NaN  2262        Sex and Candy
# ..         ...    ...   ...   ...                  ...
# 95          95  0.062  43.0   837       Desolation IPA
# 96          96  0.059   NaN  2592          Liberty Ale
# 97          97  0.065   NaN  2578                  IPA
# 98          98  0.045   NaN  2577         Summer Wheat
# 99          99  0.049   NaN  2103     California Lager
#
#                              style  brewery_id  ounces
# 0              American Pale Lager         408    12.0
# 1          American Pale Ale (APA)         177    12.0
# 2                     American IPA         177    12.0
# 3   American Double / Imperial IPA         177    12.0
# ...

# %%
craft_beers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB

# %% [raw]
# #delete unnecessary columns
# del craft_beers_df['ibu']
#
# del craft_beers_df['Unnamed: 0']
#
# del craft_beers_df['id']

# %%
#rename columns
cbeers_df_tidy = craft_beers_df.rename(columns = {'name': "craft_beer"}, inplace = False)
cbeers_df_tidy.head()
# Out:
#    Unnamed: 0    abv  ibu    id           craft_beer  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
#reorder the columns

columns_names = ["brewery_id", "craft_beer", "style", "abv", "ounces"]

cbeers_df_tidy2 = cbeers_df_tidy.reindex(columns = columns_names)

cbeers_df_tidy2
# Out:
#       brewery_id            craft_beer                           style    abv  \
# 0            408              Pub Beer             American Pale Lager  0.050
# 1            177           Devil's Cup         American Pale Ale (APA)  0.066
# 2            177   Rise of the Phoenix                    American IPA  0.071
# 3            177              Sinister  American Double / Imperial IPA  0.090
# 4            177         Sex and Candy                    American IPA  0.075
# ...          ...                   ...                             ...    ...
# 2405         424             Belgorado                     Belgian IPA  0.067
# 2406         424         Rail Yard Ale        American Amber / Red Ale  0.052
# 2407         424       B3K Black Lager                     Schwarzbier  0.055
# 2408         424   Silverback Pale Ale         American Pale Ale (APA)  0.055
# 2409         424  Rail Yard Ale (2009)        American Amber / Red Ale  0.052
#
#       ounces
# 0       12.0
# ...

# %%
cbeers_df_final.drop_duplicates(subset=["brewery_id", "craft_beer"], keep='first', inplace=True)

# %%
#rename data frame
cbeers_df_final = cbeers_df_tidy2

# %%
#brewery csv
#creating a pandas data frame with the craft beers csv file

breweries_df = pd.read_csv(brewery_file, skiprows=[0])
breweries_df.head(100)
# Out:
#     Unnamed: 0                                name           city state
# 0            0                  NorthGate Brewing     Minneapolis    MN
# 1            1           Against the Grain Brewery     Louisville    KY
# 2            2            Jack's Abby Craft Lagers     Framingham    MA
# 3            3           Mike Hess Brewing Company      San Diego    CA
# 4            4             Fort Point Beer Company  San Francisco    CA
# ..         ...                                 ...            ...   ...
# 95          95                  Blackrocks Brewery      Marquette    MA
# 96          96      Catawba Valley Brewing Company      Morganton    NC
# 97          97              Tröegs Brewing Company        Hershey    PA
# 98          98                     Mission Brewery      San Diego    CA
# 99          99  Christian Moerlein Brewing Company     Cincinnati    OH
#
# [100 rows x 4 columns]

# %%
breweries_df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                           name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]>

# %%
#rename certain columns

breweries_df_tidy = breweries_df.rename(columns = {"Unnamed: 0": "brewery_id", "name": "brewery", "state": "state_"}, inplace = False)
breweries_df_tidy
# Out:
#      brewery_id                        brewery           city state_
# 0             0             NorthGate Brewing     Minneapolis     MN
# 1             1      Against the Grain Brewery     Louisville     KY
# 2             2       Jack's Abby Craft Lagers     Framingham     MA
# 3             3      Mike Hess Brewing Company      San Diego     CA
# 4             4        Fort Point Beer Company  San Francisco     CA
# ..          ...                            ...            ...    ...
# 553         553            Covington Brewhouse      Covington     LA
# 554         554                Dave's Brewfarm         Wilson     WI
# 555         555          Ukiah Brewing Company          Ukiah     CA
# 556         556        Butternuts Beer and Ale  Garrattsville     NY
# 557         557  Sleeping Lady Brewing Company      Anchorage     AK
#
# [558 rows x 4 columns]

# %%
#dataframe rename
brewery_df_final = breweries_df_tidy

# %%
#merging the dataframes together through the Brewery ID
combined_df = pd.merge(cbeers_df_final, brewery_df_final, on='Brewery ID', how='inner')
combined_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-329ba4855e49> in <module>
#       1 #merging the dataframes together through the Brewery ID
# ----> 2 combined_df = pd.merge(cbeers_df_final, brewery_df_final, on='Brewery ID', how='inner')
#       3 combined_df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
# ...

# %%
# reorder combined data frame

Combined_column_names = ["Brewery ID", "Brewery", "Craft Beer", "Style", "ABV", "Ounces", "State", "City"]

combined_df_tidy = combined_df.reindex(columns = Combined_column_names)

combined_df_tidy
# Out:
#       Brewery ID                    Brewery            Craft Beer  \
# 0            408  10 Barrel Brewing Company              Pub Beer
# 1            177        18th Street Brewery           Devil's Cup
# 2            177        18th Street Brewery   Rise of the Phoenix
# 3            177        18th Street Brewery              Sinister
# 4            177        18th Street Brewery         Sex and Candy
# ...          ...                        ...                   ...
# 2405         424    Wynkoop Brewing Company             Belgorado
# 2406         424    Wynkoop Brewing Company         Rail Yard Ale
# 2407         424    Wynkoop Brewing Company       B3K Black Lager
# 2408         424    Wynkoop Brewing Company   Silverback Pale Ale
# 2409         424    Wynkoop Brewing Company  Rail Yard Ale (2009)
#
#                                Style    ABV  Ounces State    City
# 0                American Pale Lager  0.050    12.0    OR    Bend
# ...

# %%
#reorder rows based on Brewery ID

combined_df_tidy_final = combined_df_tidy.sort_values("Brewery ID")
combined_df_tidy_final
# Out:
#       Brewery ID                        Brewery                 Craft Beer  \
# 1494           0             NorthGate Brewing               Maggie's Leap
# 1495           0             NorthGate Brewing                  Wall's End
# 1496           0             NorthGate Brewing                     Pumpion
# 1497           0             NorthGate Brewing                  Stronghold
# 1498           0             NorthGate Brewing                 Parapet ESB
# ...          ...                            ...                        ...
# 490          556        Butternuts Beer and Ale          Moo Thunder Stout
# 488          556        Butternuts Beer and Ale   Heinnieweisse Weissebier
# 489          556        Butternuts Beer and Ale            Snapperhead IPA
# 491          556        Butternuts Beer and Ale          Porkslap Pale Ale
# 1897         557  Sleeping Lady Brewing Company  Urban Wilderness Pale Ale
#
# ...
